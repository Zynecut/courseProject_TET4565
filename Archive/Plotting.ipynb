# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium


node_data=data = {
    "lat": [59.9333637, 60.3693258, 59.2327725, 60.998248, 60.600397],
    "lon": [10.5040742, 8.54187, 11.2946315, 10.511856, 11.224594],
    "info": ["Point 1 Info", "Point 2 Info", "Point 3 Info", "Point 4 Info", "Point 5 Info"]
}

df = pd.DataFrame(node_data)

# Create a base map centered around the average coordinates
m = folium.Map(location=[df['lat'].mean(), df['lon'].mean()], zoom_start=8)


# Plot each point on the map
for idx, row in df.iterrows():
    folium.Marker([row['lat'], row['lon']],
                  popup=f"<strong>{row['info']}</strong>",  # Popup with data
                  tooltip=row['info']  # Tooltip on hover
                  ).add_to(m)

# Save the map as an HTML file or display it in a Jupyter notebook
# m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d45f018007c2de06639e3fa61f2bc895 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d45f018007c2de06639e3fa61f2bc895&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d45f018007c2de06639e3fa61f2bc895 = L.map(
#                 &quot;map_d45f018007c2de06639e3fa61f2bc895&quot;,
#                 {
#                     center: [60.22682139999999, 10.41540514],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c07b68b494eb04aaddf097e5e362ad2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8c07b68b494eb04aaddf097e5e362ad2.addTo(map_d45f018007c2de06639e3fa61f2bc895);
#
#
#             var marker_6bee2ead75f78865dc908fdbaf9693aa = L.marker(
#                 [59.9333637, 10.5040742],
#                 {}
#             ).addTo(map_d45f018007c2de06639e3fa61f2bc895);
#
#
#         var popup_a4091785fbd5c76295616d010847bd4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b7f5559aef3871b8eff65010e4edc98f = $(`&lt;div id=&quot;html_b7f5559aef3871b8eff65010e4edc98f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Point 1 Info&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_a4091785fbd5c76295616d010847bd4c.setContent(html_b7f5559aef3871b8eff65010e4edc98f);
#
#
#
#         marker_6bee2ead75f78865dc908fdbaf9693aa.bindPopup(popup_a4091785fbd5c76295616d010847bd4c)
#         ;
#
#
#
#
#             marker_6bee2ead75f78865dc908fdbaf9693aa.bindTooltip(
#                 `&lt;div&gt;
#                      Point 1 Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_584f7468aff15e36348b5a6092576196 = L.marker(
#                 [60.3693258, 8.54187],
#                 {}
#             ).addTo(map_d45f018007c2de06639e3fa61f2bc895);
#
#
#         var popup_1775b57157438f28281f6d4c35167110 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c53da161a25076ac140022a0e5cb01c = $(`&lt;div id=&quot;html_2c53da161a25076ac140022a0e5cb01c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Point 2 Info&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_1775b57157438f28281f6d4c35167110.setContent(html_2c53da161a25076ac140022a0e5cb01c);
#
#
#
#         marker_584f7468aff15e36348b5a6092576196.bindPopup(popup_1775b57157438f28281f6d4c35167110)
#         ;
#
#
#
#
#             marker_584f7468aff15e36348b5a6092576196.bindTooltip(
#                 `&lt;div&gt;
#                      Point 2 Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c6db548b320b09ad3f730709681d76d8 = L.marker(
#                 [59.2327725, 11.2946315],
#                 {}
#             ).addTo(map_d45f018007c2de06639e3fa61f2bc895);
#
#
#         var popup_e347ecc2fc970916c9f75cda800b22c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9a1854b260b743a3f0372355ffb28ff = $(`&lt;div id=&quot;html_a9a1854b260b743a3f0372355ffb28ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Point 3 Info&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_e347ecc2fc970916c9f75cda800b22c1.setContent(html_a9a1854b260b743a3f0372355ffb28ff);
#
#
#
#         marker_c6db548b320b09ad3f730709681d76d8.bindPopup(popup_e347ecc2fc970916c9f75cda800b22c1)
#         ;
#
#
#
#
#             marker_c6db548b320b09ad3f730709681d76d8.bindTooltip(
#                 `&lt;div&gt;
#                      Point 3 Info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4b071ff1fb6d6e0479ee05531723a59b = L.marker(
#                 [60.998248, 10.511856],
#                 {}
#             ).addTo(map_d45f018007c2de06639e3fa61f2bc895);
#
#
#         var popup_4bed446d787e1241a371412459f09254 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cddabc36dceee6658de63c8b51aa269 = $(`&lt;div id=&quot;html_3cddabc36dceee6658de63c8b51aa269&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Point 4 Info&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_4bed446d787e1241a371412459f09254.setContent(html_3cddabc36dceee6658de63c8b51aa269);
#
#
#
#         marker_4b071ff1fb6d6e0479ee05531723a59b.bindPopup(popup_4bed446d787e1241a371412459f09254)
#         ;
#
#
#
#
#             marker_4b071ff1fb6d6e0479ee05531723a59b.bindTooltip(
#                 `&lt;div&gt;
#                      Point 4 Info
#                  &lt;/div&gt;

# %%
# Plot production data
